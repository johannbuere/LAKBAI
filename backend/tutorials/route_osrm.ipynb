# %%
#for tutorial usage only. this is not part of our project
import folium

from folium import Map
from pydantic import BaseModel


class Point(BaseModel):
    lat: float
    longg: float

def get_folium_map(center: Point, points: list[Point], zoom_level: int = 14) -> Map:
    folium_map = folium.Map(location=[center.lat, center.longg], zoom_start=zoom_level)

    for point in points:
        folium.Marker(location=[point.lat, point.longg], popup='Point').add_to(folium_map)
    return folium_map

#examples 
# no1 13.174019, 123.750013 -> Bahay ko lmao
point_1 = Point(lat=13.173991938817364, longg=123.74993419280142)
# no2 13.144499960685334, 123.7226020150628 -> bu main
point_2 = Point(lat=13.144499960685334, longg=123.7226020150628)
#center point -> 13.160920164457547, 123.73989775927346 (basta leg toh, gitna ng dalawa)
center_point = Point(lat=13.160920164457547, longg=123.73989775927346)

folium_map = get_folium_map(center_point, [point_1, point_2])
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35b5888ac13112c158889326e851daab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35b5888ac13112c158889326e851daab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35b5888ac13112c158889326e851daab = L.map(
#                 &quot;map_35b5888ac13112c158889326e851daab&quot;,
#                 {
#                     center: [13.160920164457547, 123.73989775927346],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_049e8f57330b88ad80c889387de1911e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_049e8f57330b88ad80c889387de1911e.addTo(map_35b5888ac13112c158889326e851daab);
#
#
#             var marker_6e5237b165274b8084e1f309905cd706 = L.marker(
#                 [13.173991938817364, 123.74993419280142],
#                 {
# }
#             ).addTo(map_35b5888ac13112c158889326e851daab);
#
#
#         var popup_0b430201089182a52f34f824147325b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a976e8f0f87a75ac59f3195a3301d9e = $(`&lt;div id=&quot;html_0a976e8f0f87a75ac59f3195a3301d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_0b430201089182a52f34f824147325b6.setContent(html_0a976e8f0f87a75ac59f3195a3301d9e);
#
#
#
#         marker_6e5237b165274b8084e1f309905cd706.bindPopup(popup_0b430201089182a52f34f824147325b6)
#         ;
#
#
#
#
#             var marker_bed684280cae7bf14df84633cac6841f = L.marker(
#                 [13.144499960685334, 123.7226020150628],
#                 {
# }
#             ).addTo(map_35b5888ac13112c158889326e851daab);
#
#
#         var popup_2620fb40d0bcb34ba8a6c13be289aafb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00a5c6cd7e6a763b7d2f505139c5c785 = $(`&lt;div id=&quot;html_00a5c6cd7e6a763b7d2f505139c5c785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_2620fb40d0bcb34ba8a6c13be289aafb.setContent(html_00a5c6cd7e6a763b7d2f505139c5c785);
#
#
#
#         marker_bed684280cae7bf14df84633cac6841f.bindPopup(popup_2620fb40d0bcb34ba8a6c13be289aafb)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
service = 'route'
version = 'v1'
profile = 'driving'
host = 'http://localhost:5000'

# %%
import requests

points = [point_1, point_2]
coordinates = ';'.join(
    [f'{point.longg},{point.lat}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{
    coordinates}?overview=full&steps=true&geometries=geojson"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['code', 'routes', 'waypoints'])

# %%
routes = data['routes']
print(f"Found {len(routes)} route(s)")
# Out:
# Found 1 route(s)

# %%
route = routes[0]
route_coordinates = route['geometry']["coordinates"]
route_distance = route["distance"]  # unit: meters
route_duration = route["duration"]  # unit: seconds

route_coordinates[:5]
# Out:
# [[123.749932, 13.174012],
#  [123.749982, 13.174016],
#  [123.750171, 13.174032],
#  [123.750201, 13.174038],
#  [123.751002, 13.174128]]

# %%
route_coordinates = [[point[1], point[0]] for point in route_coordinates]
route_coordinates[:5]
# Out:
# [[13.174012, 123.749932],
#  [13.174016, 123.749982],
#  [13.174032, 123.750171],
#  [13.174038, 123.750201],
#  [13.174128, 123.751002]]

# %%
folium_map = get_folium_map(center_point, [point_1, point_2])
popup_text = f"Distance: {route_distance} meters<br>Duration: {
    route_duration} seconds"
popup = folium.Popup(popup_text, max_width=300)

folium.PolyLine(
    locations=route_coordinates, color='blue', weight=5, popup=popup).add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f562e4abb248df9537ca7fe2ad79767 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f562e4abb248df9537ca7fe2ad79767&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f562e4abb248df9537ca7fe2ad79767 = L.map(
#                 &quot;map_8f562e4abb248df9537ca7fe2ad79767&quot;,
#                 {
#                     center: [13.160920164457547, 123.73989775927346],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74eb0a10f2b102f4a698a0112d6cf62c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74eb0a10f2b102f4a698a0112d6cf62c.addTo(map_8f562e4abb248df9537ca7fe2ad79767);
#
#
#             var marker_467b4b62962d8fe40b64d487c1327850 = L.marker(
#                 [13.173991938817364, 123.74993419280142],
#                 {
# }
#             ).addTo(map_8f562e4abb248df9537ca7fe2ad79767);
#
#
#         var popup_9c9ee7ccddc46208e1b244dcf942ef11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d5e3ed339bf13ebeb37bda700c4c073 = $(`&lt;div id=&quot;html_6d5e3ed339bf13ebeb37bda700c4c073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_9c9ee7ccddc46208e1b244dcf942ef11.setContent(html_6d5e3ed339bf13ebeb37bda700c4c073);
#
#
#
#         marker_467b4b62962d8fe40b64d487c1327850.bindPopup(popup_9c9ee7ccddc46208e1b244dcf942ef11)
#         ;
#
#
#
#
#             var marker_6deaf311259548559f7db4220444e87a = L.marker(
#                 [13.144499960685334, 123.7226020150628],
#                 {
# }
#             ).addTo(map_8f562e4abb248df9537ca7fe2ad79767);
#
#
#         var popup_94978838389c98dedef4dab70e6c0514 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_567878239400cbf99b67a799d6bb2cd6 = $(`&lt;div id=&quot;html_567878239400cbf99b67a799d6bb2cd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_94978838389c98dedef4dab70e6c0514.setContent(html_567878239400cbf99b67a799d6bb2cd6);
#
#
#
#         marker_6deaf311259548559f7db4220444e87a.bindPopup(popup_94978838389c98dedef4dab70e6c0514)
#         ;
#
#
#
#
#             var poly_line_3c3a8d0211fa23f1ab0a240195df7037 = L.polyline(
#                 [[13.174012, 123.749932], [13.174016, 123.749982], [13.174032, 123.750171], [13.174038, 123.750201], [13.174128, 123.751002], [13.174142, 123.751105], [13.174168, 123.751375], [13.174178, 123.751473], [13.174195, 123.75198], [13.173359, 123.751904], [13.173211, 123.75189], [13.172739, 123.75184], [13.172438, 123.751817], [13.172269, 123.751803], [13.172058, 123.751788], [13.171803, 123.751769], [13.171692, 123.751759], [13.171548, 123.751746], [13.171408, 123.751738], [13.171127, 123.751718], [13.170839, 123.751697], [13.170723, 123.751687], [13.17062, 123.751679], [13.170171, 123.751652], [13.169795, 123.751636], [13.168539, 123.751555], [13.167635, 123.751519], [13.167083, 123.751497], [13.167011, 123.751494], [13.166523, 123.751473], [13.166235, 123.75146], [13.164862, 123.751398], [13.164466, 123.75138], [13.163655, 123.75134], [13.163328, 123.751327], [13.16288, 123.751309], [13.162751, 123.751302], [13.16239, 123.751283], [13.161148, 123.75123], [13.160621, 123.751213], [13.160625, 123.751012], [13.160641, 123.750696], [13.16065, 123.750392], [13.160612, 123.749417], [13.160598, 123.749095], [13.160582, 123.748605], [13.160568, 123.748211], [13.160557, 123.747938], [13.160541, 123.74749], [13.16054, 123.747138], [13.160559, 123.747079], [13.160586, 123.747033], [13.160515, 123.747005], [13.160144, 123.747021], [13.159583, 123.747051], [13.158945, 123.747051], [13.158076, 123.747085], [13.157885, 123.747084], [13.157734, 123.747116], [13.157633, 123.747174], [13.157461, 123.747323], [13.157381, 123.747353], [13.157326, 123.747363], [13.157147, 123.74737], [13.156881, 123.747374], [13.156729, 123.747331], [13.156562, 123.74724], [13.156366, 123.747133], [13.156185, 123.747046], [13.156066, 123.746985], [13.155972, 123.746962], [13.155864, 123.74698], [13.155886, 123.746858], [13.155895, 123.746631], [13.155893, 123.746303], [13.155891, 123.74557], [13.155892, 123.745418], [13.155891, 123.745378], [13.155889, 123.745315], [13.155874, 123.744856], [13.155871, 123.744527], [13.155866, 123.744278], [13.155865, 123.743943], [13.155876, 123.743672], [13.15588, 123.74358], [13.155882, 123.743329], [13.155896, 123.743149],

# %%
folium_map = get_folium_map(center_point, [point_1, point_2])

colors = ['black', 'blue']

legs = data["routes"][0]["legs"]
for i, leg in enumerate(legs):
    steps = leg["steps"]
    for step in steps:
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Leg number {i + 1}<br>
        Leg distance: {leg['distance']} meters<br>
        Leg duration: {leg['duration']} seconds<br>
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4f1341bc0ba864e599478bc8f398b8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4f1341bc0ba864e599478bc8f398b8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4f1341bc0ba864e599478bc8f398b8d = L.map(
#                 &quot;map_e4f1341bc0ba864e599478bc8f398b8d&quot;,
#                 {
#                     center: [13.160920164457547, 123.73989775927346],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0112ff57b0e95d5d531f9922e3dce99d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0112ff57b0e95d5d531f9922e3dce99d.addTo(map_e4f1341bc0ba864e599478bc8f398b8d);
#
#
#             var marker_a48d6d36b0c97b0a89c65b1c8e975ca6 = L.marker(
#                 [13.173991938817364, 123.74993419280142],
#                 {
# }
#             ).addTo(map_e4f1341bc0ba864e599478bc8f398b8d);
#
#
#         var popup_d18af76e15bd08efeadfbc80140da338 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_793ac4df17efd574b543e7d205368c1b = $(`&lt;div id=&quot;html_793ac4df17efd574b543e7d205368c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d18af76e15bd08efeadfbc80140da338.setContent(html_793ac4df17efd574b543e7d205368c1b);
#
#
#
#         marker_a48d6d36b0c97b0a89c65b1c8e975ca6.bindPopup(popup_d18af76e15bd08efeadfbc80140da338)
#         ;
#
#
#
#
#             var marker_435d84ec990331b40a095dd93c094bf1 = L.marker(
#                 [13.144499960685334, 123.7226020150628],
#                 {
# }
#             ).addTo(map_e4f1341bc0ba864e599478bc8f398b8d);
#
#
#         var popup_4f232a01f0e0131466542174cf9c1ed4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_254885c5e7cf4b7c09848900960963c9 = $(`&lt;div id=&quot;html_254885c5e7cf4b7c09848900960963c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_4f232a01f0e0131466542174cf9c1ed4.setContent(html_254885c5e7cf4b7c09848900960963c9);
#
#
#
#         marker_435d84ec990331b40a095dd93c094bf1.bindPopup(popup_4f232a01f0e0131466542174cf9c1ed4)
#         ;
#
#
#
#
#             var poly_line_a5ba1f51dfe231c52ba1819fe2e17f81 = L.polyline(
#                 [[13.174012, 123.749932], [13.174016, 123.749982], [13.174032, 123.750171], [13.174038, 123.750201], [13.174128, 123.751002], [13.174142, 123.751105], [13.174168, 123.751375], [13.174178, 123.751473], [13.174195, 123.75198]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_e4f1341bc0ba864e599478bc8f398b8d);
#
#
#         var popup_399b41f40ae950ef61ad698612ef4c30 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_eed650d412831d78ec0247f7292af265 = $(`&lt;div id=&quot;html_eed650d412831d78ec0247f7292af265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         Leg number 1&lt;br&gt;         Leg distance: 7092 meters&lt;br&gt;         Leg duration: 713.8 seconds&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_399b41f40ae950ef61ad698612ef4c30.setContent(html_eed650d412831d78ec0247f7292af265);
#
#
#
#         poly_line_a5ba1f51dfe231c52ba1819fe2e17f81.bindPopup(popup_399b41f40ae950ef61ad698612ef4c30)
#         ;
#
#
#
#
#             var poly_line_e62c3ee796539b946c24e004045b3c65 = L.polyline(
#                 [[13.174195, 123.75198], [13.173359, 123.751904], [13.173211, 123.75189], [13.172739, 123.75184], [13.172438, 123.751817], [13.172269, 123.751803], [13.172058, 123.751788], [13.171803, 123.751769], [13.171692, 123.751759], [13.171548, 123.751746], [13.171408, 123.751738], [13.171127, 123.751718], [13.170839, 123.751697], [13.170723, 123.751687], [13.17062, 123.751679], [13.170171, 123.751652], [13.169795, 123.751636], [13.168539, 123.751555], [13.167635, 123.751519], [13.167083, 123.751497], [13.167011, 123.751494], [13.166523, 123.751473], [13.166235

# %%
folium_map = get_folium_map(
    point_1, [point_1, point_2], zoom_level=16)

colors = ['black', 'blue']

legs = data["routes"][0]["legs"]
for leg in legs:
    steps = leg["steps"]
    for i, step in enumerate(steps[:2]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]
        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)
        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup)
        folium_map.add_child(polyline)
    break

folium_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 19
#      11 coordinates = [[point[1], point[0]]
#      12                for point in geometry["coordinates"]]
#      13 color = colors[i % len(colors)]
#      14 popup_text = f"""
#      15 Distance: {step['distance']} meters
#      16 <br>Duration: {step['duration']} seconds
#      17 <br>Name: {step['name']}
#      18 <br>Driving side: {step['driving_side']}
# ---> 19 <br>Instruction: {step['maneuver']['modifier']}
#      20 <br>Type of maneuver: {step['maneuver']['type']}
#      21 <br>Intersections: {len(step['intersections'])}
#      22 """
#      23 popup = folium.Popup(popup_text, max_width=300)
#      24 polyline = folium.PolyLine(
#      25     locations=coordinates, color=color, weight=6, popup=popup)
#
# KeyError: 'modifier'

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
pprint(step)
# Out:
# {'distance': 223.1,
#  'driving_side': 'right',
#  'duration': 34.9,
#  'geometry': {'coordinates': [[123.749932, 13.174012],
#                               [123.749982, 13.174016],
#                               [123.750171, 13.174032],
#                               [123.750201, 13.174038],
#                               [123.751002, 13.174128],
#                               [123.751105, 13.174142],
#                               [123.751375, 13.174168],
#                               [123.751473, 13.174178],
#                               [123.75198, 13.174195]],
#               'type': 'LineString'},
#  'intersections': [{'bearings': [85],
#                     'entry': [True],
#                     'location': [123.749932, 13.174012],
#                     'out': 0},
#                    {'bearings': [90, 180, 270],
#                     'entry': [True, True, False],
#                     'in': 2,
#                     'location': [123.749982, 13.174016],
#                     'out': 0},
#                    {'bearings': [75, 180, 270],
#                     'entry': [True, True, False],
#                     'in': 2,
#                     'location': [123.750171, 13.174032],
#                     'out': 0},
#                    {'bearings': [0, 90, 255],
#                     'entry': [True, True, False],
#                     'in': 2,
#                     'location': [123.750201, 13.174038],
#                     'out': 1},
#                    {'bearings': [0, 90, 180, 270],
#                     'entry': [True, True, True, False],
#                     'in': 3,
#                     'location': [123.751002, 13.174128],
#                     'out': 1},
#                    {'bearings': [90, 180, 270],
#                     'entry': [True, True, False],
#                     'in': 2,
#                     'location': [123.751375, 13.174168],
#                     'out': 0}],
#  'maneuver': {'bearing_after': 85,
#               'bearing_before': 0,
#               'location': [123.749932, 13.174012],
#               'type': 'depart'},
#  'mode': 'driving',
#  'name': '',
#  'weight': 34.9}

# %%
import math


def add_compass(folium_map: Map, location: tuple, bearing: int, size: int = 50):

    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color="red",
        weight=2,
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2], zoom_level=16)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        maneuver_location = step["maneuver"]["location"]
        bearing = step["maneuver"].get("bearing_after", 0)
        add_compass(
            folium_map=folium_map,
            location=(maneuver_location[1], maneuver_location[0]),
            bearing=bearing
        )

folium_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 42
#      33 coordinates = [[point[1], point[0]]
#      34                for point in geometry["coordinates"]]
#      35 color = colors[i % len(colors)]
#      37 popup_text = f"""
#      38 Distance: {step['distance']} meters
#      39 <br>Duration: {step['duration']} seconds
#      40 <br>Name: {step['name']}
#      41 <br>Driving side: {step['driving_side']}
# ---> 42 <br>Instruction: {step['maneuver']['modifier']}
#      43 <br>Type of maneuver: {step['maneuver']['type']}
#      44 <br>Intersections: {len(step['intersections'])}
#      45 """
#      46 popup = folium.Popup(popup_text, max_width=300)
#      48 polyline = folium.PolyLine(
#      49     locations=coordinates, color=color, weight=6, popup=popup
#      50 )
#
# KeyError: 'modifier'

# %%
from pprint import pprint

leg = data["routes"][0]["legs"][0]
step = leg["steps"][0]
intersections = step["intersections"]
pprint(intersections)

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: red;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°",
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2], zoom_level=18)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[:1]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map

# %%
import math


def add_compass(
    folium_map: Map,
    location: tuple,
    bearing: int,
    size: int = 50,
    color: str = "red",
    weight: int = 2
):
    lat, lon = location
    end_lat = lat + (math.cos(math.radians(bearing)) * size * 1e-5)
    end_lon = lon + (math.sin(math.radians(bearing)) * size * 1e-5)

    folium.Marker(
        location=location,
        icon=folium.DivIcon(
            html="""<div style="font-size: 12px; color: black;">📍</div>"""),
    ).add_to(folium_map)

    folium.PolyLine(
        locations=[location, (end_lat, end_lon)],
        color=color,
        weight=weight,
        tooltip=f"Bearing: {bearing}°"
    ).add_to(folium_map)


folium_map = get_folium_map(
    point_1, [point_1, point_2], zoom_level=20)

colors = ['black', 'blue']
legs = data["routes"][0]["legs"]
for leg in legs[:1]:
    steps = leg["steps"]
    for i, step in enumerate(steps[:1]):
        geometry = step["geometry"]
        coordinates = [[point[1], point[0]]
                       for point in geometry["coordinates"]]
        color = colors[i % len(colors)]

        popup_text = f"""
        Distance: {step['distance']} meters
        <br>Duration: {step['duration']} seconds
        <br>Name: {step['name']}
        <br>Driving side: {step['driving_side']}
        <br>Instruction: {step['maneuver']['modifier']}
        <br>Type of maneuver: {step['maneuver']['type']}
        <br>Intersections: {len(step['intersections'])}
        """
        popup = folium.Popup(popup_text, max_width=300)

        polyline = folium.PolyLine(
            locations=coordinates, color=color, weight=6, popup=popup
        )
        folium_map.add_child(polyline)

        intersections = step["intersections"]
        for intersection in intersections[1:]:
            location = intersection["location"]
            bearings = intersection["bearings"]
            for j, bearing in enumerate(bearings):
                allowed_for_traversal = intersection["entry"][j]
                add_compass(
                    folium_map=folium_map,
                    location=(location[1], location[0]),
                    bearing=bearing,
                    color="green" if allowed_for_traversal else "red",
                    weight=5
                )

folium_map

# %%
weight = route["weight"]
weight_name = route["weight_name"]
duration = route["duration"]
distance = route["distance"]

print(f"Weight: {weight} - {weight_name}")
print(f"Duration: {duration} seconds")
print(f"Distance: {distance} meters")

# %%
import requests

points = [point_1, point_2]
coordinates = ';'.join(
    [f'{point.longg},{point.lat}' for point in points])

url = f"{host}/{service}/{version}/{profile}/{
    coordinates}?alternatives=3&overview=full&steps=true&geometries=geojson"

response = requests.get(url)
data = response.json()
routes = data['routes']
print(f"Found {len(routes)} route(s)")
